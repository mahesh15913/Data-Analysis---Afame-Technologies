# %%
import pandas as pd
import numpy as np
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\mahii\\OneDrive\\Desktop\\DataAnalysis_Afame_Technologies\\HR Data.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data = data.convert_dtypes()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   Int64
#  1   Attrition                 1470 non-null   string
#  2   BusinessTravel            1470 non-null   string
#  3   DailyRate                 1470 non-null   Int64
#  4   Department                1470 non-null   string
#  5   DistanceFromHome          1470 non-null   Int64
#  6   Education                 1470 non-null   Int64
#  7   EducationField            1470 non-null   string
#  8   EmployeeCount             1470 non-null   Int64
#  9   EmployeeNumber            1470 non-null   Int64
#  10  EnvironmentSatisfaction   1470 non-null   Int64
#  11  Gender                    1470 non-null   string
#  12  HourlyRate                1470 non-null   Int64
#  13  JobInvolvement            1470 non-null   Int64
# ...

# %%
data.describe()
# Out:
#             Age   DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count    1470.0      1470.0            1470.0     1470.0         1470.0
# mean   36.92381  802.485714          9.192517   2.912925            1.0
# std    9.135373    403.5091          8.106864   1.024165            0.0
# min        18.0       102.0               1.0        1.0            1.0
# 25%        30.0       465.0               2.0        2.0            1.0
# 50%        36.0       802.0               7.0        3.0            1.0
# 75%        43.0      1157.0              14.0        4.0            1.0
# max        60.0      1499.0              29.0        5.0            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count          1470.0                   1470.0      1470.0          1470.0
# mean      1024.865306                 2.721769   65.891156        2.729932
# std        602.024335                 1.093082   20.329428        0.711561
# ...

# %%
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.histplot(data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
integer_columns = data.select_dtypes(include = ['int64'])

# %%
integer_columns.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
integer_columns = integer_columns.astype('float64')

# %%
sns.heatmap(integer_columns[['TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']])
# Out:
# <Axes: >

# %%
sns.heatmap(integer_columns[['PerformanceRating', 'RelationshipSatisfaction', 'JobSatisfaction', 'EnvironmentSatisfaction','WorkLifeBalance','JobInvolvement', 'JobLevel','Education']])
# Out:
# <Axes: >

# %%
ax = sns.countplot(data=data,x = 'OverTime', hue='Attrition')
for p in ax.patches:
    height = p.get_height()
    ax.annotate('{:1.0f}'.format(height), (p.get_x() + p.get_width() / 2., height + 3), ha='center')

plt.show()

# %%
import matplotlib.cm as cm
sns.lineplot(data, x = 'TotalWorkingYears', y = data.groupby('TotalWorkingYears').size() , hue='Attrition')
# Out:
# <Axes: xlabel='TotalWorkingYears', ylabel='None'>

# %%
sns.lineplot(data, x = 'TrainingTimesLastYear', y = data.groupby('TrainingTimesLastYear').size() , hue='Attrition')
# Out:
# <Axes: xlabel='TrainingTimesLastYear', ylabel='None'>

# %%
sns.lineplot(data, x = 'YearsAtCompany', y = data.groupby('YearsAtCompany').size() , hue='Attrition')
# Out:
# <Axes: xlabel='YearsAtCompany', ylabel='None'>

# %%
sns.lineplot(data, x =  'YearsInCurrentRole', y = data.groupby('YearsInCurrentRole').size() , hue='Attrition')
# Out:
# <Axes: xlabel='YearsInCurrentRole', ylabel='None'>

# %%
sns.lineplot(data, x = 'YearsSinceLastPromotion', y = data.groupby('YearsSinceLastPromotion').size() , hue='Attrition')
# Out:
# <Axes: xlabel='YearsSinceLastPromotion', ylabel='None'>

# %%
sns.lineplot(data, x = 'YearsWithCurrManager', y = data.groupby('YearsWithCurrManager').size() , hue='Attrition')
# Out:
# <Axes: xlabel='YearsWithCurrManager', ylabel='None'>

# %%
labels = data['MaritalStatus'].unique()
sizes = data['MaritalStatus'].value_counts()
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
sns.countplot(x='JobRole', hue='Attrition', data=data)
# Out:
# <Axes: xlabel='JobRole', ylabel='count'>

# %%
pivot_table = data.pivot_table(values='EmployeeCount', index='EducationField', columns='Education', aggfunc='size')


sns.heatmap(pivot_table, annot=True, fmt='d')
plt.show()

# %%
pivot_table = data.pivot_table(values='EmployeeCount', index='JobRole', columns='JobLevel', aggfunc='size')


sns.heatmap(pivot_table, annot=True, fmt='0.0f', cmap='YlGnBu')
plt.show()

# %%
ax = sns.countplot(data, x = 'Gender',hue= 'Attrition')

for p in ax.patches:
    height = p.get_height()
    ax.annotate('{:1.0f}'.format(height), (p.get_x() + p.get_width() / 2., height + 3), ha='center')

plt.show()

# %%
labels = data['BusinessTravel'].unique()
sizes = data['BusinessTravel'].value_counts()
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
ax= sns.countplot(data,x='Department',hue='Attrition')

for p in ax.patches:
    height = p.get_height()
    ax.annotate('{:1.0f}'.format(height), (p.get_x() + p.get_width() / 2., height + 3), ha='center')

plt.show()
